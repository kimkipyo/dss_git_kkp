# %% [markdown]
# # 1T_Pandas로 배우는 SQL 시작하기 (1) - WHERE, ORDER BY

# %% [markdown]
# ### 갯수 세기 (COUNT)
# ### 칼럼명 변경하기 (AS)
# ### 정렬 (ORDER BY)
# ### 특정 조건에 대한 필터링(WHERE)
#
# ### Pandas에서는
# * JOIN ( merge ) ( * )
# * GROUP BY ( * )

# %% [markdown]
# #### 잠시 주석에 대해서

# %%
def hello():
    """
    주석입니다, docstring => 파이썬 코드를 문서화
    """
    pass

# 샵 이것도 주석

# %%
a = """

"""   #Multiline String입니다.

# %%
a = "여러줄
텍스트"
# Out:
#   File "<ipython-input-3-7e2db420f78f>", line 1
#     a = "여러줄
#             ^
# SyntaxError: EOL while scanning string literal

# %%
a = "여러줄\
텍스트"

# %%
a
# Out:
# '여러줄텍스트'

# %%
a = """
    안녕하세요.
    저는 김기표입니다.
"""

# %%
a
# Out:
# '\n    안녕하세요.\n    저는 김기표입니다.\n'

# %%
a.strip()
# Out:
# '안녕하세요.\n    저는 김기표입니다.'

# %%
a.replace("\n", " ")
# Out:
# '     안녕하세요.     저는 김기표입니다. '

# %%
a.replace("\n", " ").strip()
# Out:
# '안녕하세요.     저는 김기표입니다.'

# %%
import pymysql

# %%
db = pymysql.connect(
    "db.fastcamp.us",
    "root",
    "dkstncks",
    "world",
    charset="utf8",
)

SQL_QUERY = """
    SELECT *
    FROM Country
    ;
"""

country_df = pd.read_sql(SQL_QUERY, db)

# %%
# pd.read_sql("SELECT * FROM Country;", db)
# 사실 이렇게 문장을 줄여서 쓸 수 있다.

# %% [markdown]
# * SQL(Structured Query Language; 구조화된 질의 언어 == Python Programming Language)
#  * 정규표현식 같은 경우에는 하나의 약속이지 프로그래밍 언어라고 할 순 없다.
#  * 그래서 내부적으로 함수 같은 기능이 있다. count, sum, mean...
# ---
# * 연산에 대한 부분이 아니다, SQL 이런 연산에 굉장히 최적화 => 빠르게
# * 대신 느린 부분은 DATA가 100만개라면 Name, Population을 뽑아서 다운로드 받게 되면 네트워크에 대한 비용이 크게 부담된다. 그래서 10초 이상 걸리게 된다. DATA가 다 받아와 질 때까지. 그런데 만약에 COUNT를 쓰게 되면 이미 연산은 서버에서 되고 숫자만 바로 날아오는 것이다. 그러면 바로 정보를 받을 수 있는 것이다. 그래서 가능하면 SQL에서 연산이 가능한 것은 SQL에서 돌리고 pandas에서만 편하게 할 수 있는 것은 pasdas에서. 하지만 pandas가 편하기 때문에 csv로 받아와서 처리해도 되긴 하지만 계산된 데이터만 받아오는 것이 편할 경우에는 SQL에서

# %%
SQL_QUERY = """
    SELECT ____   #어떤 Column, 혹은 어떤 값을 DB로 가져올까
    FROM   ____   #어떤 Table (Excel, Sheet) 에서 정보를 가져올까
    ;
"""

# %%
SQL_QUERY = """
    SELECT *
    FROM Country
    ;
"""

# "select * from Country"   =>  똑같이 동작을 하겠지만 대문자로 쓰는 것이 약속
# ;(세미콜론) 있으나 없으나 이제는 동작하지만 그래도 끝났다는 것을 명시하기 위해 쓰는 게 낫다.

# %% [markdown]
# ### Country => Name, Population, Continent

# %%
SQL_QUERY = """
    SELECT Name, Population, Continent
    FROM Country
    ;
"""

df = pd.read_sql(SQL_QUERY, db)

# %%
df.head()
# Out:
#           Name  Population      Continent
# 0        Aruba      103000  North America
# 1  Afghanistan    22720000           Asia
# 2       Angola    12878000         Africa
# 3     Anguilla        8000  North America
# 4      Albania     3401200         Europe

# %%
country_df[["Name", "Population", "Continent"]].head()
# Out:
#           Name  Population      Continent
# 0        Aruba      103000  North America
# 1  Afghanistan    22720000           Asia
# 2       Angola    12878000         Africa
# 3     Anguilla        8000  North America
# 4      Albania     3401200         Europe

# %% [markdown]
# ### Name => 이름
# ### Poplation => 인구
# ### Continent = > 대륙으로 변경

# %%
npc_df = country_df[["Name", "Population", "Continent"]]

# %%
npc_df.rename(columns={"Name": "이름", "Population": "인구", "Continent": "대륙"})
# Out:
#                                        이름         인구             대륙
# 0                                   Aruba     103000  North America
# 1                             Afghanistan   22720000           Asia
# 2                                  Angola   12878000         Africa
# 3                                Anguilla       8000  North America
# 4                                 Albania    3401200         Europe
# 5                                 Andorra      78000         Europe
# 6                    Netherlands Antilles     217000  North America
# 7                    United Arab Emirates    2441000           Asia
# 8                               Argentina   37032000  South America
# 9                                 Armenia    3520000           Asia
# 10                         American Samoa      68000        Oceania
# 11                             Antarctica          0     Antarctica
# 12            French Southern territories          0     Antarctica
# 13                    Antigua and Barbuda      68000  North America
# 14                              Australia   18886000        Oceania
# 15                                Austria    8091800         Europe
# 16                             Azerbaijan    7734000           Asia
# 17                                Burundi    6695000         Africa
# 18                                Belgium   10239000         Europe
# 19                                  Benin    6097000         Africa
# 20                           Burkina Faso   11937000         Africa
# 21                             Bangladesh  129155000           Asia
# 22                               Bulgaria    8190900         Europe
# 23                                Bahrain     617000           Asia
# 24                                Bahamas     307000  North America
# 25                 Bosnia and Herzegovina    3972000         Europe
# 26                                Belarus   10236000         Europe
# 27                                 Belize     241000  North America
# 28                                Bermuda      65000  North America
# 29                                Bolivia    8329000  South America
# ..                                    ...        ...            ...
# 209                               Tokelau       2000        Oceania
# 210                          Turkmenistan    4459000           Asia
# 211                            East Timor     885000           Asia
# 212                                 Tonga      99000        Oceania
# 213                   Trinidad and Tobago    1295000  North America
# 214                               Tunisia    9586000         Africa
# 215                                Turkey   66591000           Asia
# 216                                Tuvalu      12000        Oceania
# 217                                Taiwan   22256000           Asia
# 218                              Tanzania   33517000         Africa
# 219                                Uganda   21778000         Africa
# 220                               Ukraine   50456000         Europe
# 221  United States Minor Outlying Islands          0        Oceania
# 222                               Uruguay    3337000  South America
# 223                         United States  278357000  North America
# 224                            Uzbekistan   24318000           Asia
# 225         Holy See (Vatican City State)       1000         Europe
# 226      Saint Vincent and the Grenadines     114000  North America
# 227                             Venezuela   24170000  South America
# 228               Virgin Islands, British      21000  North America
# 229                  Virgin Islands, U.S.      93000  North America
# 230                               Vietnam   79832000           Asia
# 231                               Vanuatu     190000        Oceania
# 232                     Wallis and Futuna      15000        Oceania
# 233                                 Samoa     180000        Oceania
# 234                                 Yemen   18112000           Asia
# 235                            Yugoslavia   10640000         Europe
# 236                          South Africa   40377000         Africa
# 237                                Zambia    9169000         Africa
# 238                              Zimbabwe   11669000         Africa
#
# [239 rows x 3 columns]

# %%
SQL_QUERY = """
    SELECT Name AS "이름", Population AS "인구수", Continent AS "대륙"
    FROM Country
    ;
"""

pd.read_sql(SQL_QUERY, db)
# Out:
#                                        이름        인구수             대륙
# 0                                   Aruba     103000  North America
# 1                             Afghanistan   22720000           Asia
# 2                                  Angola   12878000         Africa
# 3                                Anguilla       8000  North America
# 4                                 Albania    3401200         Europe
# 5                                 Andorra      78000         Europe
# 6                    Netherlands Antilles     217000  North America
# 7                    United Arab Emirates    2441000           Asia
# 8                               Argentina   37032000  South America
# 9                                 Armenia    3520000           Asia
# 10                         American Samoa      68000        Oceania
# 11                             Antarctica          0     Antarctica
# 12            French Southern territories          0     Antarctica
# 13                    Antigua and Barbuda      68000  North America
# 14                              Australia   18886000        Oceania
# 15                                Austria    8091800         Europe
# 16                             Azerbaijan    7734000           Asia
# 17                                Burundi    6695000         Africa
# 18                                Belgium   10239000         Europe
# 19                                  Benin    6097000         Africa
# 20                           Burkina Faso   11937000         Africa
# 21                             Bangladesh  129155000           Asia
# 22                               Bulgaria    8190900         Europe
# 23                                Bahrain     617000           Asia
# 24                                Bahamas     307000  North America
# 25                 Bosnia and Herzegovina    3972000         Europe
# 26                                Belarus   10236000         Europe
# 27                                 Belize     241000  North America
# 28                                Bermuda      65000  North America
# 29                                Bolivia    8329000  South America
# ..                                    ...        ...            ...
# 209                               Tokelau       2000        Oceania
# 210                          Turkmenistan    4459000           Asia
# 211                            East Timor     885000           Asia
# 212                                 Tonga      99000        Oceania
# 213                   Trinidad and Tobago    1295000  North America
# 214                               Tunisia    9586000         Africa
# 215                                Turkey   66591000           Asia
# 216                                Tuvalu      12000        Oceania
# 217                                Taiwan   22256000           Asia
# 218                              Tanzania   33517000         Africa
# 219                                Uganda   21778000         Africa
# 220                               Ukraine   50456000         Europe
# 221  United States Minor Outlying Islands          0        Oceania
# 222                               Uruguay    3337000  South America
# 223                         United States  278357000  North America
# 224                            Uzbekistan   24318000           Asia
# 225         Holy See (Vatican City State)       1000         Europe
# 226      Saint Vincent and the Grenadines     114000  North America
# 227                             Venezuela   24170000  South America
# 228               Virgin Islands, British      21000  North America
# 229                  Virgin Islands, U.S.      93000  North America
# 230                               Vietnam   79832000           Asia
# 231                               Vanuatu     190000        Oceania
# 232                     Wallis and Futuna      15000        Oceania
# 233                                 Samoa     180000        Oceania
# 234                                 Yemen   18112000           Asia
# 235                            Yugoslavia   10640000         Europe
# 236                          South Africa   40377000         Africa
# 237                                Zambia    9169000         Africa
# 238                              Zimbabwe   11669000         Africa
#
# [239 rows x 3 columns]

# %%
SQL_QUERY = """
    SELECT Name "이름", Population "인구수", Continent "대륙"
    FROM Country
    ;
"""
# AS가 없어도 동일하게 동작한다. 이건 없이 써도 됩니다.
pd.read_sql(SQL_QUERY, db)
# Out:
#                                        이름        인구수             대륙
# 0                                   Aruba     103000  North America
# 1                             Afghanistan   22720000           Asia
# 2                                  Angola   12878000         Africa
# 3                                Anguilla       8000  North America
# 4                                 Albania    3401200         Europe
# 5                                 Andorra      78000         Europe
# 6                    Netherlands Antilles     217000  North America
# 7                    United Arab Emirates    2441000           Asia
# 8                               Argentina   37032000  South America
# 9                                 Armenia    3520000           Asia
# 10                         American Samoa      68000        Oceania
# 11                             Antarctica          0     Antarctica
# 12            French Southern territories          0     Antarctica
# 13                    Antigua and Barbuda      68000  North America
# 14                              Australia   18886000        Oceania
# 15                                Austria    8091800         Europe
# 16                             Azerbaijan    7734000           Asia
# 17                                Burundi    6695000         Africa
# 18                                Belgium   10239000         Europe
# 19                                  Benin    6097000         Africa
# 20                           Burkina Faso   11937000         Africa
# 21                             Bangladesh  129155000           Asia
# 22                               Bulgaria    8190900         Europe
# 23                                Bahrain     617000           Asia
# 24                                Bahamas     307000  North America
# 25                 Bosnia and Herzegovina    3972000         Europe
# 26                                Belarus   10236000         Europe
# 27                                 Belize     241000  North America
# 28                                Bermuda      65000  North America
# 29                                Bolivia    8329000  South America
# ..                                    ...        ...            ...
# 209                               Tokelau       2000        Oceania
# 210                          Turkmenistan    4459000           Asia
# 211                            East Timor     885000           Asia
# 212                                 Tonga      99000        Oceania
# 213                   Trinidad and Tobago    1295000  North America
# 214                               Tunisia    9586000         Africa
# 215                                Turkey   66591000           Asia
# 216                                Tuvalu      12000        Oceania
# 217                                Taiwan   22256000           Asia
# 218                              Tanzania   33517000         Africa
# 219                                Uganda   21778000         Africa
# 220                               Ukraine   50456000         Europe
# 221  United States Minor Outlying Islands          0        Oceania
# 222                               Uruguay    3337000  South America
# 223                         United States  278357000  North America
# 224                            Uzbekistan   24318000           Asia
# 225         Holy See (Vatican City State)       1000         Europe
# 226      Saint Vincent and the Grenadines     114000  North America
# 227                             Venezuela   24170000  South America
# 228               Virgin Islands, British      21000  North America
# 229                  Virgin Islands, U.S.      93000  North America
# 230                               Vietnam   79832000           Asia
# 231                               Vanuatu     190000        Oceania
# 232                     Wallis and Futuna      15000        Oceania
# 233                                 Samoa     180000        Oceania
# 234                                 Yemen   18112000           Asia
# 235                            Yugoslavia   10640000         Europe
# 236                          South Africa   40377000         Africa
# 237                                Zambia    9169000         Africa
# 238                              Zimbabwe   11669000         Africa
#
# [239 rows x 3 columns]

# %%
country_df.count()
# Out:
# Code              239
# Name              239
# Continent         239
# Region            239
# SurfaceArea       239
# IndepYear         192
# Population        239
# LifeExpectancy    222
# GNP               239
# GNPOld            178
# LocalName         239
# GovernmentForm    239
# HeadOfState       238
# Capital           232
# Code2             239
# dtype: int64

# %%
len(country_df)
# Out:
# 239

# %%
SQL_QUERY = """
    SELECT COUNT(*)
    FROM Country;
"""

pd.read_sql(SQL_QUERY, db)
# Out:
#    COUNT(*)
# 0       239

# %%
SQL_QUERY = """
    SELECT COUNT(*) "count"
    FROM Country;
"""

pd.read_sql(SQL_QUERY, db)
# Out:
#    count
# 0    239

# %%
SQL_QUERY = """
    SELECT SUM(Population)
    FROM Country;
"""
#SQL에는 SUM, AVG 등 다양한 내장함수가 있다.
pd.read_sql(SQL_QUERY, db)
# Out:
#    SUM(Population)
# 0     6.078749e+09

# %% [markdown]
# #### 만약 어떤 데이터의 숫자만을 세야 하는 상황이라면? Pandas or SQL? SQL이 좋다.

# %%
import time

# %%
start_time = time.time()

#여기서부터 시작
count = len(pd.read_sql("SELECT * FROM Country;", db))
print(count)

end_time = time.time()

excute_time = end_time - start_time
print(excute_time)
# Out:
# 239
# 0.04600262641906738

# %%
start_time = time.time()

#여기서부터 시작
pd.read_sql("SELECT COUNT(*) FROM Country;", db)

end_time = time.time()

excute_time = end_time - start_time
print(excute_time)
# Out:
# 0.01000070571899414

# %% [markdown]
# * SQL은 이런 연산에 굉장히 최적화 되어 있기 때문에 다른 언어보다 빠르다.
# * 대신에 느린 부분은?
#  * 데이터가 100만개라면. Name, Population 등을 뽑을 때 다운로드 받아야 한다.
#  * 네트워크에 대한 비용이 걸린다. 다운 받는 속도 때문에 오래 걸린다.
# * 그래서 빠르게 하는 방법은? SQL에서 가능한 연산은 SQL에서 돌리고 받는 것이 좋다.

# %% [markdown]
# ### 조건에 따른 Filtering
# * Continent == Europe
# * Population > 10,000,000 데이터를 뽑아라

# %%
is_europe = country_df["Continent"] == "Europe" 
is_population = country_df["Population"] > 10000000

# %%
country_df[is_europe][is_population]
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   if __name__ == '__main__':
#     Code                Name Continent           Region  SurfaceArea  \
# 18   BEL             Belgium    Europe   Western Europe      30518.0
# 26   BLR             Belarus    Europe   Eastern Europe     207600.0
# 55   CZE      Czech Republic    Europe   Eastern Europe      78866.0
# 56   DEU             Germany    Europe   Western Europe     357022.0
# 66   ESP               Spain    Europe  Southern Europe     505992.0
# 72   FRA              France    Europe   Western Europe     551500.0
# 76   GBR      United Kingdom    Europe  British Islands     242900.0
# 85   GRC              Greece    Europe  Southern Europe     131626.0
# 97   HUN             Hungary    Europe   Eastern Europe      93030.0
# 106  ITA               Italy    Europe  Southern Europe     301316.0
# 158  NLD         Netherlands    Europe   Western Europe      41526.0
# 171  POL              Poland    Europe   Eastern Europe     323250.0
# 180  ROM             Romania    Europe   Eastern Europe     238391.0
# 181  RUS  Russian Federation    Europe   Eastern Europe   17075400.0
# 220  UKR             Ukraine    Europe   Eastern Europe     603700.0
# 235  YUG          Yugoslavia    Europe  Southern Europe     102173.0
#
#      IndepYear  Population  LifeExpectancy        GNP     GNPOld  \
# 18      1830.0    10239000            77.8   249704.0   243948.0
# 26      1991.0    10236000            68.0    13714.0        NaN
# 55      1993.0    10278100            74.5    55017.0    52037.0
# 56      1955.0    82164700            77.4  2133367.0  2102826.0
# 66      1492.0    39441700            78.8   553233.0   532031.0
# 72       843.0    59225700            78.8  1424285.0  1392448.0
# 76      1066.0    59623400            77.7  1378330.0  1296830.0
# 85      1830.0    10545700            78.4   120724.0   119946.0
# 97      1918.0    10043200            71.4    48267.0    45914.0
# 106     1861.0    57680000            79.0  1161755.0  1145372.0
# 158     1581.0    15864000            78.3   371362.0   360478.0
# 171     1918.0    38653600            73.2   151697.0   135636.0
# 180     1878.0    22455500            69.9    38158.0    34843.0
# 181     1991.0   146934000            67.2   276608.0   442989.0
# 220     1991.0    50456000            66.0    42168.0    49677.0
# 235     1918.0    10640000            72.4    17000.0        NaN
#
#            LocalName                       GovernmentForm  \
# 18   België/Belgique  Constitutional Monarchy, Federation
# 26           Belarus                             Republic
# 55             ¸esko                             Republic
# 56       Deutschland                     Federal Republic
# 66            España              Constitutional Monarchy
# 72            France                             Republic
# 76    United Kingdom              Constitutional Monarchy
# 85            Elláda                             Republic
# 97      Magyarország                             Republic
# 106           Italia                             Republic
# 158        Nederland              Constitutional Monarchy
# 171           Polska                             Republic
# 180          România                             Republic
# 181          Rossija                     Federal Republic
# 220         Ukrajina                             Republic
# 235      Jugoslavija                     Federal Republic
#
#                 HeadOfState  Capital Code2
# 18                Albert II    179.0    BE
# 26     Aljaksandr Lukašenka   3520.0    BY
# 55             Václav Havel   3339.0    CZ
# 56             Johannes Rau   3068.0    DE
# 66            Juan Carlos I    653.0    ES
# 72           Jacques Chirac   2974.0    FR
# 76             Elisabeth II    456.0    GB
# 85     Kostis Stefanopoulos   2401.0    GR
# 97              Ferenc Mádl   3483.0    HU
# 106    Carlo Azeglio Ciampi   1464.0    IT
# 158                 Beatrix      5.0    NL
# 171  Aleksander Kwasniewski   2928.0    PL
# 180             Ion Iliescu   3018.0    RO
# 181          Vladimir Putin   3580.0    RU
# 220           Leonid Kutšma   3426.0    UA
# 235      Vojislav Koštunica   1792.0    YU

# %%
# AND => 유럽에 있고, 인구가 1000만 이상인 애들
# OR => 유럽에 있거나, 인구가 1000만 이상인 애들 
# country_df[is_europe & is_population]
# country_df[is_europe | is_population]

# %%
SQL_QUERY = """
    SELECT *
    FROM Country
    WHERE 
        Continent = "Europe"
        AND Population > 10000000
    ;
"""

pd.read_sql(SQL_QUERY, db)
# Out:
#    Code                Name Continent           Region  SurfaceArea  \
# 0   BEL             Belgium    Europe   Western Europe      30518.0
# 1   BLR             Belarus    Europe   Eastern Europe     207600.0
# 2   CZE      Czech Republic    Europe   Eastern Europe      78866.0
# 3   DEU             Germany    Europe   Western Europe     357022.0
# 4   ESP               Spain    Europe  Southern Europe     505992.0
# 5   FRA              France    Europe   Western Europe     551500.0
# 6   GBR      United Kingdom    Europe  British Islands     242900.0
# 7   GRC              Greece    Europe  Southern Europe     131626.0
# 8   HUN             Hungary    Europe   Eastern Europe      93030.0
# 9   ITA               Italy    Europe  Southern Europe     301316.0
# 10  NLD         Netherlands    Europe   Western Europe      41526.0
# 11  POL              Poland    Europe   Eastern Europe     323250.0
# 12  ROM             Romania    Europe   Eastern Europe     238391.0
# 13  RUS  Russian Federation    Europe   Eastern Europe   17075400.0
# 14  UKR             Ukraine    Europe   Eastern Europe     603700.0
# 15  YUG          Yugoslavia    Europe  Southern Europe     102173.0
#
#     IndepYear  Population  LifeExpectancy        GNP     GNPOld  \
# 0        1830    10239000            77.8   249704.0   243948.0
# 1        1991    10236000            68.0    13714.0        NaN
# 2        1993    10278100            74.5    55017.0    52037.0
# 3        1955    82164700            77.4  2133367.0  2102826.0
# 4        1492    39441700            78.8   553233.0   532031.0
# 5         843    59225700            78.8  1424285.0  1392448.0
# 6        1066    59623400            77.7  1378330.0  1296830.0
# 7        1830    10545700            78.4   120724.0   119946.0
# 8        1918    10043200            71.4    48267.0    45914.0
# 9        1861    57680000            79.0  1161755.0  1145372.0
# 10       1581    15864000            78.3   371362.0   360478.0
# 11       1918    38653600            73.2   151697.0   135636.0
# 12       1878    22455500            69.9    38158.0    34843.0
# 13       1991   146934000            67.2   276608.0   442989.0
# 14       1991    50456000            66.0    42168.0    49677.0
# 15       1918    10640000            72.4    17000.0        NaN
#
#           LocalName                       GovernmentForm  \
# 0   België/Belgique  Constitutional Monarchy, Federation
# 1           Belarus                             Republic
# 2             ¸esko                             Republic
# 3       Deutschland                     Federal Republic
# 4            España              Constitutional Monarchy
# 5            France                             Republic
# 6    United Kingdom              Constitutional Monarchy
# 7            Elláda                             Republic
# 8      Magyarország                             Republic
# 9            Italia                             Republic
# 10        Nederland              Constitutional Monarchy
# 11           Polska                             Republic
# 12          România                             Republic
# 13          Rossija                     Federal Republic
# 14         Ukrajina                             Republic
# 15      Jugoslavija                     Federal Republic
#
#                HeadOfState  Capital Code2
# 0                Albert II      179    BE
# 1     Aljaksandr Lukašenka     3520    BY
# 2             Václav Havel     3339    CZ
# 3             Johannes Rau     3068    DE
# 4            Juan Carlos I      653    ES
# 5           Jacques Chirac     2974    FR
# 6             Elisabeth II      456    GB
# 7     Kostis Stefanopoulos     2401    GR
# 8              Ferenc Mádl     3483    HU
# 9     Carlo Azeglio Ciampi     1464    IT
# 10                 Beatrix        5    NL
# 11  Aleksander Kwasniewski     2928    PL
# 12             Ion Iliescu     3018    RO
# 13          Vladimir Putin     3580    RU
# 14           Leonid Kutšma     3426    UA
# 15      Vojislav Koštunica     1792    YU

# %% [markdown]
# ### Asia나 혹은 Europe에 속하는 국가를 1.pandas 2.sql 둘 다 뽑아보기

# %% [markdown]
# ### 정답 4가지
# ### 1. pandas (1)

# %%
is_asia = country_df["Continent"] == "Asia"
is_europe = country_df["Continent"] == "Europe"

# %%
country_df[is_asia | is_europe]
# Out:
#     Code                           Name Continent                     Region  \
# 1    AFG                    Afghanistan      Asia  Southern and Central Asia
# 4    ALB                        Albania    Europe            Southern Europe
# 5    AND                        Andorra    Europe            Southern Europe
# 7    ARE           United Arab Emirates      Asia                Middle East
# 9    ARM                        Armenia      Asia                Middle East
# 15   AUT                        Austria    Europe             Western Europe
# 16   AZE                     Azerbaijan      Asia                Middle East
# 18   BEL                        Belgium    Europe             Western Europe
# 21   BGD                     Bangladesh      Asia  Southern and Central Asia
# 22   BGR                       Bulgaria    Europe             Eastern Europe
# 23   BHR                        Bahrain      Asia                Middle East
# 25   BIH         Bosnia and Herzegovina    Europe            Southern Europe
# 26   BLR                        Belarus    Europe             Eastern Europe
# 32   BRN                         Brunei      Asia             Southeast Asia
# 33   BTN                         Bhutan      Asia  Southern and Central Asia
# 39   CHE                    Switzerland    Europe             Western Europe
# 41   CHN                          China      Asia               Eastern Asia
# 54   CYP                         Cyprus      Asia                Middle East
# 55   CZE                 Czech Republic    Europe             Eastern Europe
# 56   DEU                        Germany    Europe             Western Europe
# 59   DNK                        Denmark    Europe           Nordic Countries
# 66   ESP                          Spain    Europe            Southern Europe
# 67   EST                        Estonia    Europe           Baltic Countries
# 69   FIN                        Finland    Europe           Nordic Countries
# 72   FRA                         France    Europe             Western Europe
# 73   FRO                  Faroe Islands    Europe           Nordic Countries
# 76   GBR                 United Kingdom    Europe            British Islands
# 77   GEO                        Georgia      Asia                Middle East
# 79   GIB                      Gibraltar    Europe            Southern Europe
# 85   GRC                         Greece    Europe            Southern Europe
# ..   ...                            ...       ...                        ...
# 163  OMN                           Oman      Asia                Middle East
# 164  PAK                       Pakistan      Asia  Southern and Central Asia
# 168  PHL                    Philippines      Asia             Southeast Asia
# 171  POL                         Poland    Europe             Eastern Europe
# 173  PRK                    North Korea      Asia               Eastern Asia
# 174  PRT                       Portugal    Europe            Southern Europe
# 176  PSE                      Palestine      Asia                Middle East
# 178  QAT                          Qatar      Asia                Middle East
# 180  ROM                        Romania    Europe             Eastern Europe
# 181  RUS             Russian Federation    Europe             Eastern Europe
# 183  SAU                   Saudi Arabia      Asia                Middle East
# 186  SGP                      Singapore      Asia             Southeast Asia
# 189  SJM         Svalbard and Jan Mayen    Europe           Nordic Countries
# 193  SMR                     San Marino    Europe            Southern Europe
# 198  SVK                       Slovakia    Europe             Eastern Europe
# 199  SVN                       Slovenia    Europe            Southern Europe
# 200  SWE                         Sweden    Europe           Nordic Countries
# 203  SYR                          Syria      Asia                Middle East
# 207  THA                       Thailand      Asia             Southeast Asia
# 208  TJK                     Tajikistan      Asia  Southern and Central Asia
# 210  TKM                   Turkmenistan      Asia  Southern and Central Asia
# 211  TMP                     East Timor      Asia             Southeast Asia
# 215  TUR                         Turkey      Asia                Middle East
# 217  TWN                         Taiwan      Asia               Eastern Asia
# 220  UKR                        Ukraine    Europe             Eastern Europe
# 224  UZB                     Uzbekistan      Asia  Southern and Central Asia
# 225  VAT  Holy See (Vatican City State)    Europe            Southern Europe
# 230  VNM                        Vietnam      Asia             Southeast Asia
# 234  YEM                          Yemen      Asia                Middle East
# 235  YUG                     Yugoslavia    Europe            Southern Europe
#
#      SurfaceArea  IndepYear  Population  LifeExpectancy        GNP     GNPOld  \
# 1       652090.0     1919.0    22720000            45.9     5976.0        NaN
# 4        28748.0     1912.0     3401200            71.6     3205.0     2500.0
# 5          468.0     1278.0       78000            83.5     1630.0        NaN
# 7        83600.0     1971.0     2441000            74.1    37966.0    36846.0
# 9        29800.0     1991.0     3520000            66.4     1813.0     1627.0
# 15       83859.0     1918.0     8091800            77.7   211860.0   206025.0
# 16       86600.0     1991.0     7734000            62.9     4127.0     4100.0
# 18       30518.0     1830.0    10239000            77.8   249704.0   243948.0
# 21      143998.0     1971.0   129155000            60.2    32852.0    31966.0
# 22      110994.0     1908.0     8190900            70.9    12178.0    10169.0
# 23         694.0     1971.0      617000            73.0     6366.0     6097.0
# 25       51197.0     1992.0     3972000            71.5     2841.0        NaN
# 26      207600.0     1991.0    10236000            68.0    13714.0        NaN
# 32        5765.0     1984.0      328000            73.6    11705.0    12460.0
# 33       47000.0     1910.0     2124000            52.4      372.0      383.0
# 39       41284.0     1499.0     7160400            79.6   264478.0   256092.0
# 41     9572900.0    -1523.0  1277558000            71.4   982268.0   917719.0
# 54        9251.0     1960.0      754700            76.7     9333.0     8246.0
# 55       78866.0     1993.0    10278100            74.5    55017.0    52037.0
# 56      357022.0     1955.0    82164700            77.4  2133367.0  2102826.0
# 59       43094.0      800.0     5330000            76.5   174099.0   169264.0
# 66      505992.0     1492.0    39441700            78.8   553233.0   532031.0
# 67       45227.0     1991.0     1439200            69.5     5328.0     3371.0
# 69      338145.0     1917.0     5171300            77.4   121914.0   119833.0
# 72      551500.0      843.0    59225700            78.8  1424285.0  1392448.0
# 73        1399.0        NaN       43000            78.4        0.0        NaN
# 76      242900.0     1066.0    59623400            77.7  1378330.0  1296830.0
# 77       69700.0     1991.0     4968000            64.5     6064.0     5924.0
# 79           6.0        NaN       25000            79.0      258.0        NaN
# 85      131626.0     1830.0    10545700            78.4   120724.0   119946.0
# ..           ...        ...         ...             ...        ...        ...
# 163     309500.0     1951.0     2542000            71.8    16904.0    16153.0
# 164     796095.0     1947.0   156483000            61.1    61289.0    58549.0
# 168     300000.0     1946.0    75967000            67.5    65107.0    82239.0
# 171     323250.0     1918.0    38653600            73.2   151697.0   135636.0
# 173     120538.0     1948.0    24039000            70.7     5332.0        NaN
# 174      91982.0     1143.0     9997600            75.8   105954.0   102133.0
# 176       6257.0        NaN     3101000            71.4     4173.0        NaN
# 178      11000.0     1971.0      599000            72.4     9472.0     8920.0
# 180     238391.0     1878.0    22455500            69.9    38158.0    34843.0
# 181   17075400.0     1991.0   146934000            67.2   276608.0   442989.0
# 183    2149690.0     1932.0    21607000            67.8   137635.0   146171.0
# 186        618.0     1965.0     3567000            80.1    86503.0    96318.0
# 189      62422.0        NaN        3200             NaN        0.0        NaN
# 193         61.0      885.0       27000            81.1      510.0        NaN
# 198      49012.0     1993.0     5398700            73.7    20594.0    19452.0
# 199      20256.0     1991.0     1987800            74.9    19756.0    18202.0
# 200     449964.0      836.0     8861400            79.6   226492.0   227757.0
# 203     185180.0     1941.0    16125000            68.5    65984.0    64926.0
# 207     513115.0     1350.0    61399000            68.6   116416.0   153907.0
# 208     143100.0     1991.0     6188000            64.1     1990.0     1056.0
# 210     488100.0     1991.0     4459000            60.9     4397.0     2000.0
# 211      14874.0        NaN      885000            46.0        0.0        NaN
# 215     774815.0     1923.0    66591000            71.0   210721.0   189122.0
# 217      36188.0     1945.0    22256000            76.4   256254.0   263451.0
# 220     603700.0     1991.0    50456000            66.0    42168.0    49677.0
# 224     447400.0     1991.0    24318000            63.7    14194.0    21300.0
# 225          0.4     1929.0        1000             NaN        9.0        NaN
# 230     331689.0     1945.0    79832000            69.3    21929.0    22834.0
# 234     527968.0     1918.0    18112000            59.8     6041.0     5729.0
# 235     102173.0     1918.0    10640000            72.4    17000.0        NaN
#
#                                        LocalName  \
# 1                          Afganistan/Afqanestan
# 4                                      Shqipëria
# 5                                        Andorra
# 7             Al-Imarat al-´Arabiya al-Muttahida
# 9                                       Hajastan
# 15                                    Österreich
# 16                                    Azärbaycan
# 18                               België/Belgique
# 21                                    Bangladesh
# 22                                     Balgarija
# 23                                    Al-Bahrayn
# 25                           Bosna i Hercegovina
# 26                                       Belarus
# 32                             Brunei Darussalam
# 33                                      Druk-Yul
# 39                Schweiz/Suisse/Svizzera/Svizra
# 41                                      Zhongquo
# 54                                 Kýpros/Kibris
# 55                                         ¸esko
# 56                                   Deutschland
# 59                                       Danmark
# 66                                        España
# 67                                         Eesti
# 69                                         Suomi
# 72                                        France
# 73                                       Føroyar
# 76                                United Kingdom
# 77                                    Sakartvelo
# 79                                     Gibraltar
# 85                                        Elláda
# ..                                           ...
# 163                                        ´Uman
# 164                                     Pakistan
# 168                                    Pilipinas
# 171                                       Polska
# 173  Choson Minjujuui In´min Konghwaguk (Bukhan)
# 174                                     Portugal
# 176                                     Filastin
# 178                                        Qatar
# 180                                      România
# 181                                      Rossija
# 183                      Al-´Arabiya as-Sa´udiya
# 186        Singapore/Singapura/Xinjiapo/Singapur
# 189                        Svalbard og Jan Mayen
# 193                                   San Marino
# 198                                    Slovensko
# 199                                    Slovenija
# 200                                      Sverige
# 203                                       Suriya
# 207                                 Prathet Thai
# 208                                   Toçikiston
# 210                                 Türkmenostan
# 211                                  Timor Timur
# 215                                      Türkiye
# 217                                     T’ai-wan
# 220                                     Ukrajina
# 224                                   Uzbekiston
# 225                Santa Sede/Città del Vaticano
# 230                                     Viêt Nam
# 234                                     Al-Yaman
# 235                                  Jugoslavija
#
#                           GovernmentForm                   HeadOfState  \
# 1                        Islamic Emirate                 Mohammad Omar
# 4                               Republic                Rexhep Mejdani
# 5           Parliamentary Coprincipality
# 7                     Emirate Federation   Zayid bin Sultan al-Nahayan
# 9                               Republic              Robert Kotšarjan
# 15                      Federal Republic                Thomas Klestil
# 16                      Federal Republic                 Heydär Äliyev
# 18   Constitutional Monarchy, Federation                     Albert II
# 21                              Republic             Shahabuddin Ahmad
# 22                              Republic                Petar Stojanov
# 23                    Monarchy (Emirate)      Hamad ibn Isa al-Khalifa
# 25                      Federal Republic                  Ante Jelavic
# 26                              Republic          Aljaksandr Lukašenka
# 32                  Monarchy (Sultanate)        Haji Hassan al-Bolkiah
# 33                              Monarchy         Jigme Singye Wangchuk
# 39                            Federation                     Adolf Ogi
# 41                      People'sRepublic                   Jiang Zemin
# 54                              Republic              Glafkos Klerides
# 55                              Republic                  Václav Havel
# 56                      Federal Republic                  Johannes Rau
# 59               Constitutional Monarchy                  Margrethe II
# 66               Constitutional Monarchy                 Juan Carlos I
# 67                              Republic                  Lennart Meri
# 69                              Republic                 Tarja Halonen
# 72                              Republic                Jacques Chirac
# 73                       Part of Denmark                  Margrethe II
# 76               Constitutional Monarchy                  Elisabeth II
# 77                              Republic            Eduard Ševardnadze
# 79         Dependent Territory of the UK                  Elisabeth II
# 85                              Republic          Kostis Stefanopoulos
# ..                                   ...                           ...
# 163                 Monarchy (Sultanate)               Qabus ibn Sa´id
# 164                             Republic          Mohammad Rafiq Tarar
# 168                             Republic       Gloria Macapagal-Arroyo
# 171                             Republic        Aleksander Kwasniewski
# 173                 Socialistic Republic                   Kim Jong-il
# 174                             Republic                 Jorge Sampãio
# 176                      Autonomous Area         Yasser (Yasir) Arafat
# 178                             Monarchy    Hamad ibn Khalifa al-Thani
# 180                             Republic                   Ion Iliescu
# 181                     Federal Republic                Vladimir Putin
# 183                             Monarchy  Fahd ibn Abdul-Aziz al-Sa´ud
# 186                             Republic          Sellapan Rama Nathan
# 189        Dependent Territory of Norway                      Harald V
# 193                             Republic                          None
# 198                             Republic               Rudolf Schuster
# 199                             Republic                   Milan Kucan
# 200              Constitutional Monarchy               Carl XVI Gustaf
# 203                             Republic               Bashar al-Assad
# 207              Constitutional Monarchy            Bhumibol Adulyadej
# 208                             Republic              Emomali Rahmonov
# 210                             Republic            Saparmurad Nijazov
# 211              Administrated by the UN         José Alexandre Gusmão
# 215                             Republic            Ahmet Necdet Sezer
# 217                             Republic                Chen Shui-bian
# 220                             Republic                 Leonid Kutšma
# 224                             Republic                 Islam Karimov
# 225             Independent Church State           Johannes Paavali II
# 230                 Socialistic Republic                Trân Duc Luong
# 234                             Republic            Ali Abdallah Salih
# 235                     Federal Republic            Vojislav Koštunica
#
#      Capital Code2
# 1        1.0    AF
# 4       34.0    AL
# 5       55.0    AD
# 7       65.0    AE
# 9      126.0    AM
# 15    1523.0    AT
# 16     144.0    AZ
# 18     179.0    BE
# 21     150.0    BD
# 22     539.0    BG
# 23     149.0    BH
# 25     201.0    BA
# 26    3520.0    BY
# 32     538.0    BN
# 33     192.0    BT
# 39    3248.0    CH
# 41    1891.0    CN
# 54    2430.0    CY
# 55    3339.0    CZ
# 56    3068.0    DE
# 59    3315.0    DK
# 66     653.0    ES
# 67    3791.0    EE
# 69    3236.0    FI
# 72    2974.0    FR
# 73     901.0    FO
# 76     456.0    GB
# 77     905.0    GE
# 79     915.0    GI
# 85    2401.0    GR
# ..       ...   ...
# 163   2821.0    OM
# 164   2831.0    PK
# 168    766.0    PH
# 171   2928.0    PL
# 173   2318.0    KP
# 174   2914.0    PT
# 176   4074.0    PS
# 178   2973.0    QA
# 180   3018.0    RO
# 181   3580.0    RU
# 183   3173.0    SA
# 186   3208.0    SG
# 189    938.0    SJ
# 193   3171.0    SM
# 198   3209.0    SK
# 199   3212.0    SI
# 200   3048.0    SE
# 203   3250.0    SY
# 207   3320.0    TH
# 208   3261.0    TJ
# 210   3419.0    TM
# 211   1522.0    TP
# 215   3358.0    TR
# 217   3263.0    TW
# 220   3426.0    UA
# 224   3503.0    UZ
# 225   3538.0    VA
# 230   3770.0    VN
# 234   1780.0    YE
# 235   1792.0    YU
#
# [97 rows x 15 columns]

# %% [markdown]
# ### 2. pandas (2)

# %%
is_asia_or_europe = country_df["Continent"].isin(["Asia", "Europe"])
country_df[is_asia_or_europe].head(3)
# Out:
#   Code         Name Continent                     Region  SurfaceArea  \
# 1  AFG  Afghanistan      Asia  Southern and Central Asia     652090.0
# 4  ALB      Albania    Europe            Southern Europe      28748.0
# 5  AND      Andorra    Europe            Southern Europe        468.0
#
#    IndepYear  Population  LifeExpectancy     GNP  GNPOld  \
# 1     1919.0    22720000            45.9  5976.0     NaN
# 4     1912.0     3401200            71.6  3205.0  2500.0
# 5     1278.0       78000            83.5  1630.0     NaN
#
#                LocalName                GovernmentForm     HeadOfState  \
# 1  Afganistan/Afqanestan               Islamic Emirate   Mohammad Omar
# 4              Shqipëria                      Republic  Rexhep Mejdani
# 5                Andorra  Parliamentary Coprincipality
#
#    Capital Code2
# 1      1.0    AF
# 4     34.0    AL
# 5     55.0    AD

# %%
# df["Continent"].str.contains("Asia")  =>  이건 텍스트마이닝 방법

# %% [markdown]
# ### 3. sql (1)

# %%
SQL_QUERY = """
    SELECT *
    FROM Country
    WHERE
        Continent = "Asia"
        OR Continent = "Europe"
"""

pd.read_sql(SQL_QUERY, db)
# Out:
#    Code                           Name Continent                     Region  \
# 0   AFG                    Afghanistan      Asia  Southern and Central Asia
# 1   ALB                        Albania    Europe            Southern Europe
# 2   AND                        Andorra    Europe            Southern Europe
# 3   ARE           United Arab Emirates      Asia                Middle East
# 4   ARM                        Armenia      Asia                Middle East
# 5   AUT                        Austria    Europe             Western Europe
# 6   AZE                     Azerbaijan      Asia                Middle East
# 7   BEL                        Belgium    Europe             Western Europe
# 8   BGD                     Bangladesh      Asia  Southern and Central Asia
# 9   BGR                       Bulgaria    Europe             Eastern Europe
# 10  BHR                        Bahrain      Asia                Middle East
# 11  BIH         Bosnia and Herzegovina    Europe            Southern Europe
# 12  BLR                        Belarus    Europe             Eastern Europe
# 13  BRN                         Brunei      Asia             Southeast Asia
# 14  BTN                         Bhutan      Asia  Southern and Central Asia
# 15  CHE                    Switzerland    Europe             Western Europe
# 16  CHN                          China      Asia               Eastern Asia
# 17  CYP                         Cyprus      Asia                Middle East
# 18  CZE                 Czech Republic    Europe             Eastern Europe
# 19  DEU                        Germany    Europe             Western Europe
# 20  DNK                        Denmark    Europe           Nordic Countries
# 21  ESP                          Spain    Europe            Southern Europe
# 22  EST                        Estonia    Europe           Baltic Countries
# 23  FIN                        Finland    Europe           Nordic Countries
# 24  FRA                         France    Europe             Western Europe
# 25  FRO                  Faroe Islands    Europe           Nordic Countries
# 26  GBR                 United Kingdom    Europe            British Islands
# 27  GEO                        Georgia      Asia                Middle East
# 28  GIB                      Gibraltar    Europe            Southern Europe
# 29  GRC                         Greece    Europe            Southern Europe
# ..  ...                            ...       ...                        ...
# 67  OMN                           Oman      Asia                Middle East
# 68  PAK                       Pakistan      Asia  Southern and Central Asia
# 69  PHL                    Philippines      Asia             Southeast Asia
# 70  POL                         Poland    Europe             Eastern Europe
# 71  PRK                    North Korea      Asia               Eastern Asia
# 72  PRT                       Portugal    Europe            Southern Europe
# 73  PSE                      Palestine      Asia                Middle East
# 74  QAT                          Qatar      Asia                Middle East
# 75  ROM                        Romania    Europe             Eastern Europe
# 76  RUS             Russian Federation    Europe             Eastern Europe
# 77  SAU                   Saudi Arabia      Asia                Middle East
# 78  SGP                      Singapore      Asia             Southeast Asia
# 79  SJM         Svalbard and Jan Mayen    Europe           Nordic Countries
# 80  SMR                     San Marino    Europe            Southern Europe
# 81  SVK                       Slovakia    Europe             Eastern Europe
# 82  SVN                       Slovenia    Europe            Southern Europe
# 83  SWE                         Sweden    Europe           Nordic Countries
# 84  SYR                          Syria      Asia                Middle East
# 85  THA                       Thailand      Asia             Southeast Asia
# 86  TJK                     Tajikistan      Asia  Southern and Central Asia
# 87  TKM                   Turkmenistan      Asia  Southern and Central Asia
# 88  TMP                     East Timor      Asia             Southeast Asia
# 89  TUR                         Turkey      Asia                Middle East
# 90  TWN                         Taiwan      Asia               Eastern Asia
# 91  UKR                        Ukraine    Europe             Eastern Europe
# 92  UZB                     Uzbekistan      Asia  Southern and Central Asia
# 93  VAT  Holy See (Vatican City State)    Europe            Southern Europe
# 94  VNM                        Vietnam      Asia             Southeast Asia
# 95  YEM                          Yemen      Asia                Middle East
# 96  YUG                     Yugoslavia    Europe            Southern Europe
#
#     SurfaceArea  IndepYear  Population  LifeExpectancy        GNP     GNPOld  \
# 0      652090.0     1919.0    22720000            45.9     5976.0        NaN
# 1       28748.0     1912.0     3401200            71.6     3205.0     2500.0
# 2         468.0     1278.0       78000            83.5     1630.0        NaN
# 3       83600.0     1971.0     2441000            74.1    37966.0    36846.0
# 4       29800.0     1991.0     3520000            66.4     1813.0     1627.0
# 5       83859.0     1918.0     8091800            77.7   211860.0   206025.0
# 6       86600.0     1991.0     7734000            62.9     4127.0     4100.0
# 7       30518.0     1830.0    10239000            77.8   249704.0   243948.0
# 8      143998.0     1971.0   129155000            60.2    32852.0    31966.0
# 9      110994.0     1908.0     8190900            70.9    12178.0    10169.0
# 10        694.0     1971.0      617000            73.0     6366.0     6097.0
# 11      51197.0     1992.0     3972000            71.5     2841.0        NaN
# 12     207600.0     1991.0    10236000            68.0    13714.0        NaN
# 13       5765.0     1984.0      328000            73.6    11705.0    12460.0
# 14      47000.0     1910.0     2124000            52.4      372.0      383.0
# 15      41284.0     1499.0     7160400            79.6   264478.0   256092.0
# 16    9572900.0    -1523.0  1277558000            71.4   982268.0   917719.0
# 17       9251.0     1960.0      754700            76.7     9333.0     8246.0
# 18      78866.0     1993.0    10278100            74.5    55017.0    52037.0
# 19     357022.0     1955.0    82164700            77.4  2133367.0  2102826.0
# 20      43094.0      800.0     5330000            76.5   174099.0   169264.0
# 21     505992.0     1492.0    39441700            78.8   553233.0   532031.0
# 22      45227.0     1991.0     1439200            69.5     5328.0     3371.0
# 23     338145.0     1917.0     5171300            77.4   121914.0   119833.0
# 24     551500.0      843.0    59225700            78.8  1424285.0  1392448.0
# 25       1399.0        NaN       43000            78.4        0.0        NaN
# 26     242900.0     1066.0    59623400            77.7  1378330.0  1296830.0
# 27      69700.0     1991.0     4968000            64.5     6064.0     5924.0
# 28          6.0        NaN       25000            79.0      258.0        NaN
# 29     131626.0     1830.0    10545700            78.4   120724.0   119946.0
# ..          ...        ...         ...             ...        ...        ...
# 67     309500.0     1951.0     2542000            71.8    16904.0    16153.0
# 68     796095.0     1947.0   156483000            61.1    61289.0    58549.0
# 69     300000.0     1946.0    75967000            67.5    65107.0    82239.0
# 70     323250.0     1918.0    38653600            73.2   151697.0   135636.0
# 71     120538.0     1948.0    24039000            70.7     5332.0        NaN
# 72      91982.0     1143.0     9997600            75.8   105954.0   102133.0
# 73       6257.0        NaN     3101000            71.4     4173.0        NaN
# 74      11000.0     1971.0      599000            72.4     9472.0     8920.0
# 75     238391.0     1878.0    22455500            69.9    38158.0    34843.0
# 76   17075400.0     1991.0   146934000            67.2   276608.0   442989.0
# 77    2149690.0     1932.0    21607000            67.8   137635.0   146171.0
# 78        618.0     1965.0     3567000            80.1    86503.0    96318.0
# 79      62422.0        NaN        3200             NaN        0.0        NaN
# 80         61.0      885.0       27000            81.1      510.0        NaN
# 81      49012.0     1993.0     5398700            73.7    20594.0    19452.0
# 82      20256.0     1991.0     1987800            74.9    19756.0    18202.0
# 83     449964.0      836.0     8861400            79.6   226492.0   227757.0
# 84     185180.0     1941.0    16125000            68.5    65984.0    64926.0
# 85     513115.0     1350.0    61399000            68.6   116416.0   153907.0
# 86     143100.0     1991.0     6188000            64.1     1990.0     1056.0
# 87     488100.0     1991.0     4459000            60.9     4397.0     2000.0
# 88      14874.0        NaN      885000            46.0        0.0        NaN
# 89     774815.0     1923.0    66591000            71.0   210721.0   189122.0
# 90      36188.0     1945.0    22256000            76.4   256254.0   263451.0
# 91     603700.0     1991.0    50456000            66.0    42168.0    49677.0
# 92     447400.0     1991.0    24318000            63.7    14194.0    21300.0
# 93          0.4     1929.0        1000             NaN        9.0        NaN
# 94     331689.0     1945.0    79832000            69.3    21929.0    22834.0
# 95     527968.0     1918.0    18112000            59.8     6041.0     5729.0
# 96     102173.0     1918.0    10640000            72.4    17000.0        NaN
#
#                                       LocalName  \
# 0                         Afganistan/Afqanestan
# 1                                     Shqipëria
# 2                                       Andorra
# 3            Al-Imarat al-´Arabiya al-Muttahida
# 4                                      Hajastan
# 5                                    Österreich
# 6                                    Azärbaycan
# 7                               België/Belgique
# 8                                    Bangladesh
# 9                                     Balgarija
# 10                                   Al-Bahrayn
# 11                          Bosna i Hercegovina
# 12                                      Belarus
# 13                            Brunei Darussalam
# 14                                     Druk-Yul
# 15               Schweiz/Suisse/Svizzera/Svizra
# 16                                     Zhongquo
# 17                                Kýpros/Kibris
# 18                                        ¸esko
# 19                                  Deutschland
# 20                                      Danmark
# 21                                       España
# 22                                        Eesti
# 23                                        Suomi
# 24                                       France
# 25                                      Føroyar
# 26                               United Kingdom
# 27                                   Sakartvelo
# 28                                    Gibraltar
# 29                                       Elláda
# ..                                          ...
# 67                                        ´Uman
# 68                                     Pakistan
# 69                                    Pilipinas
# 70                                       Polska
# 71  Choson Minjujuui In´min Konghwaguk (Bukhan)
# 72                                     Portugal
# 73                                     Filastin
# 74                                        Qatar
# 75                                      România
# 76                                      Rossija
# 77                      Al-´Arabiya as-Sa´udiya
# 78        Singapore/Singapura/Xinjiapo/Singapur
# 79                        Svalbard og Jan Mayen
# 80                                   San Marino
# 81                                    Slovensko
# 82                                    Slovenija
# 83                                      Sverige
# 84                                       Suriya
# 85                                 Prathet Thai
# 86                                   Toçikiston
# 87                                 Türkmenostan
# 88                                  Timor Timur
# 89                                      Türkiye
# 90                                     T’ai-wan
# 91                                     Ukrajina
# 92                                   Uzbekiston
# 93                Santa Sede/Città del Vaticano
# 94                                     Viêt Nam
# 95                                     Al-Yaman
# 96                                  Jugoslavija
#
#                          GovernmentForm                   HeadOfState  \
# 0                       Islamic Emirate                 Mohammad Omar
# 1                              Republic                Rexhep Mejdani
# 2          Parliamentary Coprincipality
# 3                    Emirate Federation   Zayid bin Sultan al-Nahayan
# 4                              Republic              Robert Kotšarjan
# 5                      Federal Republic                Thomas Klestil
# 6                      Federal Republic                 Heydär Äliyev
# 7   Constitutional Monarchy, Federation                     Albert II
# 8                              Republic             Shahabuddin Ahmad
# 9                              Republic                Petar Stojanov
# 10                   Monarchy (Emirate)      Hamad ibn Isa al-Khalifa
# 11                     Federal Republic                  Ante Jelavic
# 12                             Republic          Aljaksandr Lukašenka
# 13                 Monarchy (Sultanate)        Haji Hassan al-Bolkiah
# 14                             Monarchy         Jigme Singye Wangchuk
# 15                           Federation                     Adolf Ogi
# 16                     People'sRepublic                   Jiang Zemin
# 17                             Republic              Glafkos Klerides
# 18                             Republic                  Václav Havel
# 19                     Federal Republic                  Johannes Rau
# 20              Constitutional Monarchy                  Margrethe II
# 21              Constitutional Monarchy                 Juan Carlos I
# 22                             Republic                  Lennart Meri
# 23                             Republic                 Tarja Halonen
# 24                             Republic                Jacques Chirac
# 25                      Part of Denmark                  Margrethe II
# 26              Constitutional Monarchy                  Elisabeth II
# 27                             Republic            Eduard Ševardnadze
# 28        Dependent Territory of the UK                  Elisabeth II
# 29                             Republic          Kostis Stefanopoulos
# ..                                  ...                           ...
# 67                 Monarchy (Sultanate)               Qabus ibn Sa´id
# 68                             Republic          Mohammad Rafiq Tarar
# 69                             Republic       Gloria Macapagal-Arroyo
# 70                             Republic        Aleksander Kwasniewski
# 71                 Socialistic Republic                   Kim Jong-il
# 72                             Republic                 Jorge Sampãio
# 73                      Autonomous Area         Yasser (Yasir) Arafat
# 74                             Monarchy    Hamad ibn Khalifa al-Thani
# 75                             Republic                   Ion Iliescu
# 76                     Federal Republic                Vladimir Putin
# 77                             Monarchy  Fahd ibn Abdul-Aziz al-Sa´ud
# 78                             Republic          Sellapan Rama Nathan
# 79        Dependent Territory of Norway                      Harald V
# 80                             Republic                          None
# 81                             Republic               Rudolf Schuster
# 82                             Republic                   Milan Kucan
# 83              Constitutional Monarchy               Carl XVI Gustaf
# 84                             Republic               Bashar al-Assad
# 85              Constitutional Monarchy            Bhumibol Adulyadej
# 86                             Republic              Emomali Rahmonov
# 87                             Republic            Saparmurad Nijazov
# 88              Administrated by the UN         José Alexandre Gusmão
# 89                             Republic            Ahmet Necdet Sezer
# 90                             Republic                Chen Shui-bian
# 91                             Republic                 Leonid Kutšma
# 92                             Republic                 Islam Karimov
# 93             Independent Church State           Johannes Paavali II
# 94                 Socialistic Republic                Trân Duc Luong
# 95                             Republic            Ali Abdallah Salih
# 96                     Federal Republic            Vojislav Koštunica
#
#     Capital Code2
# 0         1    AF
# 1        34    AL
# 2        55    AD
# 3        65    AE
# 4       126    AM
# 5      1523    AT
# 6       144    AZ
# 7       179    BE
# 8       150    BD
# 9       539    BG
# 10      149    BH
# 11      201    BA
# 12     3520    BY
# 13      538    BN
# 14      192    BT
# 15     3248    CH
# 16     1891    CN
# 17     2430    CY
# 18     3339    CZ
# 19     3068    DE
# 20     3315    DK
# 21      653    ES
# 22     3791    EE
# 23     3236    FI
# 24     2974    FR
# 25      901    FO
# 26      456    GB
# 27      905    GE
# 28      915    GI
# 29     2401    GR
# ..      ...   ...
# 67     2821    OM
# 68     2831    PK
# 69      766    PH
# 70     2928    PL
# 71     2318    KP
# 72     2914    PT
# 73     4074    PS
# 74     2973    QA
# 75     3018    RO
# 76     3580    RU
# 77     3173    SA
# 78     3208    SG
# 79      938    SJ
# 80     3171    SM
# 81     3209    SK
# 82     3212    SI
# 83     3048    SE
# 84     3250    SY
# 85     3320    TH
# 86     3261    TJ
# 87     3419    TM
# 88     1522    TP
# 89     3358    TR
# 90     3263    TW
# 91     3426    UA
# 92     3503    UZ
# 93     3538    VA
# 94     3770    VN
# 95     1780    YE
# 96     1792    YU
#
# [97 rows x 15 columns]

# %% [markdown]
# ### 4. sql (2)

# %%
SQL_QUERY = """
    SELECT *
    FROM Country
    WHERE
        Continent IN ("Asia", "Europe")
    ;
"""

pd.read_sql(SQL_QUERY, db)
# Out:
#    Code                           Name Continent                     Region  \
# 0   AFG                    Afghanistan      Asia  Southern and Central Asia
# 1   ALB                        Albania    Europe            Southern Europe
# 2   AND                        Andorra    Europe            Southern Europe
# 3   ARE           United Arab Emirates      Asia                Middle East
# 4   ARM                        Armenia      Asia                Middle East
# 5   AUT                        Austria    Europe             Western Europe
# 6   AZE                     Azerbaijan      Asia                Middle East
# 7   BEL                        Belgium    Europe             Western Europe
# 8   BGD                     Bangladesh      Asia  Southern and Central Asia
# 9   BGR                       Bulgaria    Europe             Eastern Europe
# 10  BHR                        Bahrain      Asia                Middle East
# 11  BIH         Bosnia and Herzegovina    Europe            Southern Europe
# 12  BLR                        Belarus    Europe             Eastern Europe
# 13  BRN                         Brunei      Asia             Southeast Asia
# 14  BTN                         Bhutan      Asia  Southern and Central Asia
# 15  CHE                    Switzerland    Europe             Western Europe
# 16  CHN                          China      Asia               Eastern Asia
# 17  CYP                         Cyprus      Asia                Middle East
# 18  CZE                 Czech Republic    Europe             Eastern Europe
# 19  DEU                        Germany    Europe             Western Europe
# 20  DNK                        Denmark    Europe           Nordic Countries
# 21  ESP                          Spain    Europe            Southern Europe
# 22  EST                        Estonia    Europe           Baltic Countries
# 23  FIN                        Finland    Europe           Nordic Countries
# 24  FRA                         France    Europe             Western Europe
# 25  FRO                  Faroe Islands    Europe           Nordic Countries
# 26  GBR                 United Kingdom    Europe            British Islands
# 27  GEO                        Georgia      Asia                Middle East
# 28  GIB                      Gibraltar    Europe            Southern Europe
# 29  GRC                         Greece    Europe            Southern Europe
# ..  ...                            ...       ...                        ...
# 67  OMN                           Oman      Asia                Middle East
# 68  PAK                       Pakistan      Asia  Southern and Central Asia
# 69  PHL                    Philippines      Asia             Southeast Asia
# 70  POL                         Poland    Europe             Eastern Europe
# 71  PRK                    North Korea      Asia               Eastern Asia
# 72  PRT                       Portugal    Europe            Southern Europe
# 73  PSE                      Palestine      Asia                Middle East
# 74  QAT                          Qatar      Asia                Middle East
# 75  ROM                        Romania    Europe             Eastern Europe
# 76  RUS             Russian Federation    Europe             Eastern Europe
# 77  SAU                   Saudi Arabia      Asia                Middle East
# 78  SGP                      Singapore      Asia             Southeast Asia
# 79  SJM         Svalbard and Jan Mayen    Europe           Nordic Countries
# 80  SMR                     San Marino    Europe            Southern Europe
# 81  SVK                       Slovakia    Europe             Eastern Europe
# 82  SVN                       Slovenia    Europe            Southern Europe
# 83  SWE                         Sweden    Europe           Nordic Countries
# 84  SYR                          Syria      Asia                Middle East
# 85  THA                       Thailand      Asia             Southeast Asia
# 86  TJK                     Tajikistan      Asia  Southern and Central Asia
# 87  TKM                   Turkmenistan      Asia  Southern and Central Asia
# 88  TMP                     East Timor      Asia             Southeast Asia
# 89  TUR                         Turkey      Asia                Middle East
# 90  TWN                         Taiwan      Asia               Eastern Asia
# 91  UKR                        Ukraine    Europe             Eastern Europe
# 92  UZB                     Uzbekistan      Asia  Southern and Central Asia
# 93  VAT  Holy See (Vatican City State)    Europe            Southern Europe
# 94  VNM                        Vietnam      Asia             Southeast Asia
# 95  YEM                          Yemen      Asia                Middle East
# 96  YUG                     Yugoslavia    Europe            Southern Europe
#
#     SurfaceArea  IndepYear  Population  LifeExpectancy        GNP     GNPOld  \
# 0      652090.0     1919.0    22720000            45.9     5976.0        NaN
# 1       28748.0     1912.0     3401200            71.6     3205.0     2500.0
# 2         468.0     1278.0       78000            83.5     1630.0        NaN
# 3       83600.0     1971.0     2441000            74.1    37966.0    36846.0
# 4       29800.0     1991.0     3520000            66.4     1813.0     1627.0
# 5       83859.0     1918.0     8091800            77.7   211860.0   206025.0
# 6       86600.0     1991.0     7734000            62.9     4127.0     4100.0
# 7       30518.0     1830.0    10239000            77.8   249704.0   243948.0
# 8      143998.0     1971.0   129155000            60.2    32852.0    31966.0
# 9      110994.0     1908.0     8190900            70.9    12178.0    10169.0
# 10        694.0     1971.0      617000            73.0     6366.0     6097.0
# 11      51197.0     1992.0     3972000            71.5     2841.0        NaN
# 12     207600.0     1991.0    10236000            68.0    13714.0        NaN
# 13       5765.0     1984.0      328000            73.6    11705.0    12460.0
# 14      47000.0     1910.0     2124000            52.4      372.0      383.0
# 15      41284.0     1499.0     7160400            79.6   264478.0   256092.0
# 16    9572900.0    -1523.0  1277558000            71.4   982268.0   917719.0
# 17       9251.0     1960.0      754700            76.7     9333.0     8246.0
# 18      78866.0     1993.0    10278100            74.5    55017.0    52037.0
# 19     357022.0     1955.0    82164700            77.4  2133367.0  2102826.0
# 20      43094.0      800.0     5330000            76.5   174099.0   169264.0
# 21     505992.0     1492.0    39441700            78.8   553233.0   532031.0
# 22      45227.0     1991.0     1439200            69.5     5328.0     3371.0
# 23     338145.0     1917.0     5171300            77.4   121914.0   119833.0
# 24     551500.0      843.0    59225700            78.8  1424285.0  1392448.0
# 25       1399.0        NaN       43000            78.4        0.0        NaN
# 26     242900.0     1066.0    59623400            77.7  1378330.0  1296830.0
# 27      69700.0     1991.0     4968000            64.5     6064.0     5924.0
# 28          6.0        NaN       25000            79.0      258.0        NaN
# 29     131626.0     1830.0    10545700            78.4   120724.0   119946.0
# ..          ...        ...         ...             ...        ...        ...
# 67     309500.0     1951.0     2542000            71.8    16904.0    16153.0
# 68     796095.0     1947.0   156483000            61.1    61289.0    58549.0
# 69     300000.0     1946.0    75967000            67.5    65107.0    82239.0
# 70     323250.0     1918.0    38653600            73.2   151697.0   135636.0
# 71     120538.0     1948.0    24039000            70.7     5332.0        NaN
# 72      91982.0     1143.0     9997600            75.8   105954.0   102133.0
# 73       6257.0        NaN     3101000            71.4     4173.0        NaN
# 74      11000.0     1971.0      599000            72.4     9472.0     8920.0
# 75     238391.0     1878.0    22455500            69.9    38158.0    34843.0
# 76   17075400.0     1991.0   146934000            67.2   276608.0   442989.0
# 77    2149690.0     1932.0    21607000            67.8   137635.0   146171.0
# 78        618.0     1965.0     3567000            80.1    86503.0    96318.0
# 79      62422.0        NaN        3200             NaN        0.0        NaN
# 80         61.0      885.0       27000            81.1      510.0        NaN
# 81      49012.0     1993.0     5398700            73.7    20594.0    19452.0
# 82      20256.0     1991.0     1987800            74.9    19756.0    18202.0
# 83     449964.0      836.0     8861400            79.6   226492.0   227757.0
# 84     185180.0     1941.0    16125000            68.5    65984.0    64926.0
# 85     513115.0     1350.0    61399000            68.6   116416.0   153907.0
# 86     143100.0     1991.0     6188000            64.1     1990.0     1056.0
# 87     488100.0     1991.0     4459000            60.9     4397.0     2000.0
# 88      14874.0        NaN      885000            46.0        0.0        NaN
# 89     774815.0     1923.0    66591000            71.0   210721.0   189122.0
# 90      36188.0     1945.0    22256000            76.4   256254.0   263451.0
# 91     603700.0     1991.0    50456000            66.0    42168.0    49677.0
# 92     447400.0     1991.0    24318000            63.7    14194.0    21300.0
# 93          0.4     1929.0        1000             NaN        9.0        NaN
# 94     331689.0     1945.0    79832000            69.3    21929.0    22834.0
# 95     527968.0     1918.0    18112000            59.8     6041.0     5729.0
# 96     102173.0     1918.0    10640000            72.4    17000.0        NaN
#
#                                       LocalName  \
# 0                         Afganistan/Afqanestan
# 1                                     Shqipëria
# 2                                       Andorra
# 3            Al-Imarat al-´Arabiya al-Muttahida
# 4                                      Hajastan
# 5                                    Österreich
# 6                                    Azärbaycan
# 7                               België/Belgique
# 8                                    Bangladesh
# 9                                     Balgarija
# 10                                   Al-Bahrayn
# 11                          Bosna i Hercegovina
# 12                                      Belarus
# 13                            Brunei Darussalam
# 14                                     Druk-Yul
# 15               Schweiz/Suisse/Svizzera/Svizra
# 16                                     Zhongquo
# 17                                Kýpros/Kibris
# 18                                        ¸esko
# 19                                  Deutschland
# 20                                      Danmark
# 21                                       España
# 22                                        Eesti
# 23                                        Suomi
# 24                                       France
# 25                                      Føroyar
# 26                               United Kingdom
# 27                                   Sakartvelo
# 28                                    Gibraltar
# 29                                       Elláda
# ..                                          ...
# 67                                        ´Uman
# 68                                     Pakistan
# 69                                    Pilipinas
# 70                                       Polska
# 71  Choson Minjujuui In´min Konghwaguk (Bukhan)
# 72                                     Portugal
# 73                                     Filastin
# 74                                        Qatar
# 75                                      România
# 76                                      Rossija
# 77                      Al-´Arabiya as-Sa´udiya
# 78        Singapore/Singapura/Xinjiapo/Singapur
# 79                        Svalbard og Jan Mayen
# 80                                   San Marino
# 81                                    Slovensko
# 82                                    Slovenija
# 83                                      Sverige
# 84                                       Suriya
# 85                                 Prathet Thai
# 86                                   Toçikiston
# 87                                 Türkmenostan
# 88                                  Timor Timur
# 89                                      Türkiye
# 90                                     T’ai-wan
# 91                                     Ukrajina
# 92                                   Uzbekiston
# 93                Santa Sede/Città del Vaticano
# 94                                     Viêt Nam
# 95                                     Al-Yaman
# 96                                  Jugoslavija
#
#                          GovernmentForm                   HeadOfState  \
# 0                       Islamic Emirate                 Mohammad Omar
# 1                              Republic                Rexhep Mejdani
# 2          Parliamentary Coprincipality
# 3                    Emirate Federation   Zayid bin Sultan al-Nahayan
# 4                              Republic              Robert Kotšarjan
# 5                      Federal Republic                Thomas Klestil
# 6                      Federal Republic                 Heydär Äliyev
# 7   Constitutional Monarchy, Federation                     Albert II
# 8                              Republic             Shahabuddin Ahmad
# 9                              Republic                Petar Stojanov
# 10                   Monarchy (Emirate)      Hamad ibn Isa al-Khalifa
# 11                     Federal Republic                  Ante Jelavic
# 12                             Republic          Aljaksandr Lukašenka
# 13                 Monarchy (Sultanate)        Haji Hassan al-Bolkiah
# 14                             Monarchy         Jigme Singye Wangchuk
# 15                           Federation                     Adolf Ogi
# 16                     People'sRepublic                   Jiang Zemin
# 17                             Republic              Glafkos Klerides
# 18                             Republic                  Václav Havel
# 19                     Federal Republic                  Johannes Rau
# 20              Constitutional Monarchy                  Margrethe II
# 21              Constitutional Monarchy                 Juan Carlos I
# 22                             Republic                  Lennart Meri
# 23                             Republic                 Tarja Halonen
# 24                             Republic                Jacques Chirac
# 25                      Part of Denmark                  Margrethe II
# 26              Constitutional Monarchy                  Elisabeth II
# 27                             Republic            Eduard Ševardnadze
# 28        Dependent Territory of the UK                  Elisabeth II
# 29                             Republic          Kostis Stefanopoulos
# ..                                  ...                           ...
# 67                 Monarchy (Sultanate)               Qabus ibn Sa´id
# 68                             Republic          Mohammad Rafiq Tarar
# 69                             Republic       Gloria Macapagal-Arroyo
# 70                             Republic        Aleksander Kwasniewski
# 71                 Socialistic Republic                   Kim Jong-il
# 72                             Republic                 Jorge Sampãio
# 73                      Autonomous Area         Yasser (Yasir) Arafat
# 74                             Monarchy    Hamad ibn Khalifa al-Thani
# 75                             Republic                   Ion Iliescu
# 76                     Federal Republic                Vladimir Putin
# 77                             Monarchy  Fahd ibn Abdul-Aziz al-Sa´ud
# 78                             Republic          Sellapan Rama Nathan
# 79        Dependent Territory of Norway                      Harald V
# 80                             Republic                          None
# 81                             Republic               Rudolf Schuster
# 82                             Republic                   Milan Kucan
# 83              Constitutional Monarchy               Carl XVI Gustaf
# 84                             Republic               Bashar al-Assad
# 85              Constitutional Monarchy            Bhumibol Adulyadej
# 86                             Republic              Emomali Rahmonov
# 87                             Republic            Saparmurad Nijazov
# 88              Administrated by the UN         José Alexandre Gusmão
# 89                             Republic            Ahmet Necdet Sezer
# 90                             Republic                Chen Shui-bian
# 91                             Republic                 Leonid Kutšma
# 92                             Republic                 Islam Karimov
# 93             Independent Church State           Johannes Paavali II
# 94                 Socialistic Republic                Trân Duc Luong
# 95                             Republic            Ali Abdallah Salih
# 96                     Federal Republic            Vojislav Koštunica
#
#     Capital Code2
# 0         1    AF
# 1        34    AL
# 2        55    AD
# 3        65    AE
# 4       126    AM
# 5      1523    AT
# 6       144    AZ
# 7       179    BE
# 8       150    BD
# 9       539    BG
# 10      149    BH
# 11      201    BA
# 12     3520    BY
# 13      538    BN
# 14      192    BT
# 15     3248    CH
# 16     1891    CN
# 17     2430    CY
# 18     3339    CZ
# 19     3068    DE
# 20     3315    DK
# 21      653    ES
# 22     3791    EE
# 23     3236    FI
# 24     2974    FR
# 25      901    FO
# 26      456    GB
# 27      905    GE
# 28      915    GI
# 29     2401    GR
# ..      ...   ...
# 67     2821    OM
# 68     2831    PK
# 69      766    PH
# 70     2928    PL
# 71     2318    KP
# 72     2914    PT
# 73     4074    PS
# 74     2973    QA
# 75     3018    RO
# 76     3580    RU
# 77     3173    SA
# 78     3208    SG
# 79      938    SJ
# 80     3171    SM
# 81     3209    SK
# 82     3212    SI
# 83     3048    SE
# 84     3250    SY
# 85     3320    TH
# 86     3261    TJ
# 87     3419    TM
# 88     1522    TP
# 89     3358    TR
# 90     3263    TW
# 91     3426    UA
# 92     3503    UZ
# 93     3538    VA
# 94     3770    VN
# 95     1780    YE
# 96     1792    YU
#
# [97 rows x 15 columns]

# %% [markdown]
# ## 정렬
# ### Pandas에서 인구수 내림차순으로 정렬(즉, 인구가 많은 순서대로)

# %%
country_df.sort_values("Population", ascending=False)[["Name", "Population"]]
# Out:
#                                              Name  Population
# 41                                          China  1277558000
# 99                                          India  1013662000
# 223                                 United States   278357000
# 98                                      Indonesia   212107000
# 30                                         Brazil   170115000
# 164                                      Pakistan   156483000
# 181                            Russian Federation   146934000
# 21                                     Bangladesh   129155000
# 109                                         Japan   126714000
# 155                                       Nigeria   111506000
# 135                                        Mexico    98881000
# 56                                        Germany    82164700
# 230                                       Vietnam    79832000
# 168                                   Philippines    75967000
# 63                                          Egypt    68470000
# 102                                          Iran    67702000
# 215                                        Turkey    66591000
# 68                                       Ethiopia    62565000
# 207                                      Thailand    61399000
# 76                                 United Kingdom    59623400
# 72                                         France    59225700
# 106                                         Italy    57680000
# 44          Congo, The Democratic Republic of the    51654000
# 220                                       Ukraine    50456000
# 116                                   South Korea    46844000
# 140                                       Myanmar    45611000
# 47                                       Colombia    42321000
# 236                                  South Africa    40377000
# 66                                          Spain    39441700
# 171                                        Poland    38653600
# ..                                            ...         ...
# 123                                 Liechtenstein       32300
# 193                                    San Marino       27000
# 79                                      Gibraltar       25000
# 228                       Virgin Islands, British       21000
# 46                                   Cook Islands       20000
# 169                                         Palau       19000
# 204                      Turks and Caicos Islands       17000
# 232                             Wallis and Futuna       15000
# 216                                        Tuvalu       12000
# 161                                         Nauru       12000
# 145                                    Montserrat       11000
# 3                                        Anguilla        8000
# 195                     Saint Pierre and Miquelon        7000
# 188                                  Saint Helena        6000
# 189                        Svalbard and Jan Mayen        3200
# 52                               Christmas Island        2500
# 71                               Falkland Islands        2000
# 209                                       Tokelau        2000
# 157                                          Niue        2000
# 154                                Norfolk Island        2000
# 225                 Holy See (Vatican City State)        1000
# 38                        Cocos (Keeling) Islands         600
# 166                                      Pitcairn          50
# 11                                     Antarctica           0
# 34                                  Bouvet Island           0
# 221          United States Minor Outlying Islands           0
# 93              Heard Island and McDonald Islands           0
# 100                British Indian Ocean Territory           0
# 187  South Georgia and the South Sandwich Islands           0
# 12                    French Southern territories           0
#
# [239 rows x 2 columns]

# %% [markdown]
# * sort() - deprecated(중요도가 떨어져 더 이상 사용되지 않고 앞으로는 사라지게 될 (컴퓨터 시스템 기능 등))

# %%
country_df.sort("Population")
# Out:
# C:\Anaconda3\lib\site-packages\ipykernel\__main__.py:1: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   if __name__ == '__main__':
#     Code                                          Name      Continent  \
# 34   BVT                                 Bouvet Island     Antarctica
# 100  IOT                British Indian Ocean Territory         Africa
# 187  SGS  South Georgia and the South Sandwich Islands     Antarctica
# 11   ATA                                    Antarctica     Antarctica
# 12   ATF                   French Southern territories     Antarctica
# 221  UMI          United States Minor Outlying Islands        Oceania
# 93   HMD             Heard Island and McDonald Islands     Antarctica
# 166  PCN                                      Pitcairn        Oceania
# 38   CCK                       Cocos (Keeling) Islands        Oceania
# 225  VAT                 Holy See (Vatican City State)         Europe
# 209  TKL                                       Tokelau        Oceania
# 157  NIU                                          Niue        Oceania
# 154  NFK                                Norfolk Island        Oceania
# 71   FLK                              Falkland Islands  South America
# 52   CXR                              Christmas Island        Oceania
# 189  SJM                        Svalbard and Jan Mayen         Europe
# 188  SHN                                  Saint Helena         Africa
# 195  SPM                     Saint Pierre and Miquelon  North America
# 3    AIA                                      Anguilla  North America
# 145  MSR                                    Montserrat  North America
# 216  TUV                                        Tuvalu        Oceania
# 161  NRU                                         Nauru        Oceania
# 232  WLF                             Wallis and Futuna        Oceania
# 204  TCA                      Turks and Caicos Islands  North America
# 169  PLW                                         Palau        Oceania
# 46   COK                                  Cook Islands        Oceania
# 228  VGB                       Virgin Islands, British  North America
# 79   GIB                                     Gibraltar         Europe
# 193  SMR                                    San Marino         Europe
# 123  LIE                                 Liechtenstein         Europe
# ..   ...                                           ...            ...
# 171  POL                                        Poland         Europe
# 66   ESP                                         Spain         Europe
# 236  ZAF                                  South Africa         Africa
# 47   COL                                      Colombia  South America
# 140  MMR                                       Myanmar           Asia
# 116  KOR                                   South Korea           Asia
# 220  UKR                                       Ukraine         Europe
# 44   COD         Congo, The Democratic Republic of the         Africa
# 106  ITA                                         Italy         Europe
# 72   FRA                                        France         Europe
# 76   GBR                                United Kingdom         Europe
# 207  THA                                      Thailand           Asia
# 68   ETH                                      Ethiopia         Africa
# 215  TUR                                        Turkey           Asia
# 102  IRN                                          Iran           Asia
# 63   EGY                                         Egypt         Africa
# 168  PHL                                   Philippines           Asia
# 230  VNM                                       Vietnam           Asia
# 56   DEU                                       Germany         Europe
# 135  MEX                                        Mexico  North America
# 155  NGA                                       Nigeria         Africa
# 109  JPN                                         Japan           Asia
# 21   BGD                                    Bangladesh           Asia
# 181  RUS                            Russian Federation         Europe
# 164  PAK                                      Pakistan           Asia
# 30   BRA                                        Brazil  South America
# 98   IDN                                     Indonesia           Asia
# 223  USA                                 United States  North America
# 99   IND                                         India           Asia
# 41   CHN                                         China           Asia
#
#                         Region  SurfaceArea  IndepYear  Population  \
# 34                  Antarctica         59.0        NaN           0
# 100             Eastern Africa         78.0        NaN           0
# 187                 Antarctica       3903.0        NaN           0
# 11                  Antarctica   13120000.0        NaN           0
# 12                  Antarctica       7780.0        NaN           0
# 221       Micronesia/Caribbean         16.0        NaN           0
# 93                  Antarctica        359.0        NaN           0
# 166                  Polynesia         49.0        NaN          50
# 38   Australia and New Zealand         14.0        NaN         600
# 225            Southern Europe          0.4     1929.0        1000
# 209                  Polynesia         12.0        NaN        2000
# 157                  Polynesia        260.0        NaN        2000
# 154  Australia and New Zealand         36.0        NaN        2000
# 71               South America      12173.0        NaN        2000
# 52   Australia and New Zealand        135.0        NaN        2500
# 189           Nordic Countries      62422.0        NaN        3200
# 188             Western Africa        314.0        NaN        6000
# 195              North America        242.0        NaN        7000
# 3                    Caribbean         96.0        NaN        8000
# 145                  Caribbean        102.0        NaN       11000
# 216                  Polynesia         26.0     1978.0       12000
# 161                 Micronesia         21.0     1968.0       12000
# 232                  Polynesia        200.0        NaN       15000
# 204                  Caribbean        430.0        NaN       17000
# 169                 Micronesia        459.0     1994.0       19000
# 46                   Polynesia        236.0        NaN       20000
# 228                  Caribbean        151.0        NaN       21000
# 79             Southern Europe          6.0        NaN       25000
# 193            Southern Europe         61.0      885.0       27000
# 123             Western Europe        160.0     1806.0       32300
# ..                         ...          ...        ...         ...
# 171             Eastern Europe     323250.0     1918.0    38653600
# 66             Southern Europe     505992.0     1492.0    39441700
# 236            Southern Africa    1221037.0     1910.0    40377000
# 47               South America    1138914.0     1810.0    42321000
# 140             Southeast Asia     676578.0     1948.0    45611000
# 116               Eastern Asia      99434.0     1948.0    46844000
# 220             Eastern Europe     603700.0     1991.0    50456000
# 44              Central Africa    2344858.0     1960.0    51654000
# 106            Southern Europe     301316.0     1861.0    57680000
# 72              Western Europe     551500.0      843.0    59225700
# 76             British Islands     242900.0     1066.0    59623400
# 207             Southeast Asia     513115.0     1350.0    61399000
# 68              Eastern Africa    1104300.0    -1000.0    62565000
# 215                Middle East     774815.0     1923.0    66591000
# 102  Southern and Central Asia    1648195.0     1906.0    67702000
# 63             Northern Africa    1001449.0     1922.0    68470000
# 168             Southeast Asia     300000.0     1946.0    75967000
# 230             Southeast Asia     331689.0     1945.0    79832000
# 56              Western Europe     357022.0     1955.0    82164700
# 135            Central America    1958201.0     1810.0    98881000
# 155             Western Africa     923768.0     1960.0   111506000
# 109               Eastern Asia     377829.0     -660.0   126714000
# 21   Southern and Central Asia     143998.0     1971.0   129155000
# 181             Eastern Europe   17075400.0     1991.0   146934000
# 164  Southern and Central Asia     796095.0     1947.0   156483000
# 30               South America    8547403.0     1822.0   170115000
# 98              Southeast Asia    1904569.0     1945.0   212107000
# 223              North America    9363520.0     1776.0   278357000
# 99   Southern and Central Asia    3287263.0     1947.0  1013662000
# 41                Eastern Asia    9572900.0    -1523.0  1277558000
#
#      LifeExpectancy        GNP     GNPOld  \
# 34              NaN        0.0        NaN
# 100             NaN        0.0        NaN
# 187             NaN        0.0        NaN
# 11              NaN        0.0        NaN
# 12              NaN        0.0        NaN
# 221             NaN        0.0        NaN
# 93              NaN        0.0        NaN
# 166             NaN        0.0        NaN
# 38              NaN        0.0        NaN
# 225             NaN        9.0        NaN
# 209             NaN        0.0        NaN
# 157             NaN        0.0        NaN
# 154             NaN        0.0        NaN
# 71              NaN        0.0        NaN
# 52              NaN        0.0        NaN
# 189             NaN        0.0        NaN
# 188            76.8        0.0        NaN
# 195            77.6        0.0        NaN
# 3              76.1       63.2        NaN
# 145            78.0      109.0        NaN
# 216            66.3        6.0        NaN
# 161            60.8      197.0        NaN
# 232             NaN        0.0        NaN
# 204            73.3       96.0        NaN
# 169            68.6      105.0        NaN
# 46             71.1      100.0        NaN
# 228            75.4      612.0      573.0
# 79             79.0      258.0        NaN
# 193            81.1      510.0        NaN
# 123            78.8     1119.0     1084.0
# ..              ...        ...        ...
# 171            73.2   151697.0   135636.0
# 66             78.8   553233.0   532031.0
# 236            51.1   116729.0   129092.0
# 47             70.3   102896.0   105116.0
# 140            54.9   180375.0   171028.0
# 116            74.4   320749.0   442544.0
# 220            66.0    42168.0    49677.0
# 44             48.8     6964.0     2474.0
# 106            79.0  1161755.0  1145372.0
# 72             78.8  1424285.0  1392448.0
# 76             77.7  1378330.0  1296830.0
# 207            68.6   116416.0   153907.0
# 68             45.2     6353.0     6180.0
# 215            71.0   210721.0   189122.0
# 102            69.7   195746.0   160151.0
# 63             63.3    82710.0    75617.0
# 168            67.5    65107.0    82239.0
# 230            69.3    21929.0    22834.0
# 56             77.4  2133367.0  2102826.0
# 135            71.5   414972.0   401461.0
# 155            51.6    65707.0    58623.0
# 109            80.7  3787042.0  4192638.0
# 21             60.2    32852.0    31966.0
# 181            67.2   276608.0   442989.0
# 164            61.1    61289.0    58549.0
# 30             62.9   776739.0   804108.0
# 98             68.0    84982.0   215002.0
# 223            77.1  8510700.0  8110900.0
# 99             62.5   447114.0   430572.0
# 41             71.4   982268.0   917719.0
#
#                                         LocalName  \
# 34                                      Bouvetøya
# 100                British Indian Ocean Territory
# 187  South Georgia and the South Sandwich Islands
# 11                                              –
# 12                    Terres australes françaises
# 221          United States Minor Outlying Islands
# 93                     Heard and McDonald Islands
# 166                                      Pitcairn
# 38                        Cocos (Keeling) Islands
# 225                 Santa Sede/Città del Vaticano
# 209                                       Tokelau
# 157                                          Niue
# 154                                Norfolk Island
# 71                               Falkland Islands
# 52                               Christmas Island
# 189                         Svalbard og Jan Mayen
# 188                                  Saint Helena
# 195                      Saint-Pierre-et-Miquelon
# 3                                        Anguilla
# 145                                    Montserrat
# 216                                        Tuvalu
# 161                                  Naoero/Nauru
# 232                              Wallis-et-Futuna
# 204                  The Turks and Caicos Islands
# 169                                   Belau/Palau
# 46                               The Cook Islands
# 228                        British Virgin Islands
# 79                                      Gibraltar
# 193                                    San Marino
# 123                                 Liechtenstein
# ..                                            ...
# 171                                        Polska
# 66                                         España
# 236                                  South Africa
# 47                                       Colombia
# 140                                    Myanma Pye
# 116                       Taehan Min’guk (Namhan)
# 220                                      Ukrajina
# 44               République Démocratique du Congo
# 106                                        Italia
# 72                                         France
# 76                                 United Kingdom
# 207                                  Prathet Thai
# 68                                    YeItyop´iya
# 215                                       Türkiye
# 102                                          Iran
# 63                                           Misr
# 168                                     Pilipinas
# 230                                      Viêt Nam
# 56                                    Deutschland
# 135                                        México
# 155                                       Nigeria
# 109                                  Nihon/Nippon
# 21                                     Bangladesh
# 181                                       Rossija
# 164                                      Pakistan
# 30                                         Brasil
# 98                                      Indonesia
# 223                                 United States
# 99                                   Bharat/India
# 41                                       Zhongquo
#
#                                GovernmentForm                    HeadOfState  \
# 34              Dependent Territory of Norway                       Harald V
# 100             Dependent Territory of the UK                   Elisabeth II
# 187             Dependent Territory of the UK                   Elisabeth II
# 11                           Co-administrated
# 12        Nonmetropolitan Territory of France                 Jacques Chirac
# 221             Dependent Territory of the US                 George W. Bush
# 93                     Territory of Australia                   Elisabeth II
# 166             Dependent Territory of the UK                   Elisabeth II
# 38                     Territory of Australia                   Elisabeth II
# 225                  Independent Church State            Johannes Paavali II
# 209  Nonmetropolitan Territory of New Zealand                   Elisabeth II
# 157  Nonmetropolitan Territory of New Zealand                   Elisabeth II
# 154                    Territory of Australia                   Elisabeth II
# 71              Dependent Territory of the UK                   Elisabeth II
# 52                     Territory of Australia                   Elisabeth II
# 189             Dependent Territory of Norway                       Harald V
# 188             Dependent Territory of the UK                   Elisabeth II
# 195        Territorial Collectivity of France                 Jacques Chirac
# 3               Dependent Territory of the UK                   Elisabeth II
# 145             Dependent Territory of the UK                   Elisabeth II
# 216                   Constitutional Monarchy                   Elisabeth II
# 161                                  Republic               Bernard Dowiyogo
# 232       Nonmetropolitan Territory of France                 Jacques Chirac
# 204             Dependent Territory of the UK                   Elisabeth II
# 169                                  Republic                Kuniwo Nakamura
# 46   Nonmetropolitan Territory of New Zealand                   Elisabeth II
# 228             Dependent Territory of the UK                   Elisabeth II
# 79              Dependent Territory of the UK                   Elisabeth II
# 193                                  Republic                           None
# 123                   Constitutional Monarchy                   Hans-Adam II
# ..                                        ...                            ...
# 171                                  Republic         Aleksander Kwasniewski
# 66                    Constitutional Monarchy                  Juan Carlos I
# 236                                  Republic                    Thabo Mbeki
# 47                                   Republic         Andrés Pastrana Arango
# 140                                  Republic             kenraali Than Shwe
# 116                                  Republic                   Kim Dae-jung
# 220                                  Republic                  Leonid Kutšma
# 44                                   Republic                  Joseph Kabila
# 106                                  Republic           Carlo Azeglio Ciampi
# 72                                   Republic                 Jacques Chirac
# 76                    Constitutional Monarchy                   Elisabeth II
# 207                   Constitutional Monarchy             Bhumibol Adulyadej
# 68                                   Republic                 Negasso Gidada
# 215                                  Republic             Ahmet Necdet Sezer
# 102                          Islamic Republic  Ali Mohammad Khatami-Ardakani
# 63                                   Republic                  Hosni Mubarak
# 168                                  Republic        Gloria Macapagal-Arroyo
# 230                      Socialistic Republic                 Trân Duc Luong
# 56                           Federal Republic                   Johannes Rau
# 135                          Federal Republic            Vicente Fox Quesada
# 155                          Federal Republic              Olusegun Obasanjo
# 109                   Constitutional Monarchy                        Akihito
# 21                                   Republic              Shahabuddin Ahmad
# 181                          Federal Republic                 Vladimir Putin
# 164                                  Republic           Mohammad Rafiq Tarar
# 30                           Federal Republic      Fernando Henrique Cardoso
# 98                                   Republic              Abdurrahman Wahid
# 223                          Federal Republic                 George W. Bush
# 99                           Federal Republic       Kocheril Raman Narayanan
# 41                           People'sRepublic                    Jiang Zemin
#
#      Capital Code2
# 34       NaN    BV
# 100      NaN    IO
# 187      NaN    GS
# 11       NaN    AQ
# 12       NaN    TF
# 221      NaN    UM
# 93       NaN    HM
# 166   2912.0    PN
# 38    2317.0    CC
# 225   3538.0    VA
# 209   3333.0    TK
# 157   2805.0    NU
# 154   2806.0    NF
# 71     763.0    FK
# 52    1791.0    CX
# 189    938.0    SJ
# 188   3063.0    SH
# 195   3067.0    PM
# 3       62.0    AI
# 145   2697.0    MS
# 216   3424.0    TV
# 161   2728.0    NR
# 232   3536.0    WF
# 204   3423.0    TC
# 169   2881.0    PW
# 46     583.0    CK
# 228    537.0    VG
# 79     915.0    GI
# 193   3171.0    SM
# 123   2446.0    LI
# ..       ...   ...
# 171   2928.0    PL
# 66     653.0    ES
# 236    716.0    ZA
# 47    2257.0    CO
# 140   2710.0    MM
# 116   2331.0    KR
# 220   3426.0    UA
# 44    2298.0    CD
# 106   1464.0    IT
# 72    2974.0    FR
# 76     456.0    GB
# 207   3320.0    TH
# 68     756.0    ET
# 215   3358.0    TR
# 102   1380.0    IR
# 63     608.0    EG
# 168    766.0    PH
# 230   3770.0    VN
# 56    3068.0    DE
# 135   2515.0    MX
# 155   2754.0    NG
# 109   1532.0    JP
# 21     150.0    BD
# 181   3580.0    RU
# 164   2831.0    PK
# 30     211.0    BR
# 98     939.0    ID
# 223   3813.0    US
# 99    1109.0    IN
# 41    1891.0    CN
#
# [239 rows x 15 columns]

# %% [markdown]
# * 인구수가 1억 명 이상이면서, 아시아나 유럽에 포함된 국가들을 인구수 내림차순으로 출력하라 와 같은 문제도 풀 수 있다.

# %%
SQL_QUERY = """
    SELECT Name, Population
    FROM Country
    ORDER BY Population DESC
    ;
"""
# 기본값으로 ASC
pd.read_sql(SQL_QUERY, db)
# Out:
#                                              Name  Population
# 0                                           China  1277558000
# 1                                           India  1013662000
# 2                                   United States   278357000
# 3                                       Indonesia   212107000
# 4                                          Brazil   170115000
# 5                                        Pakistan   156483000
# 6                              Russian Federation   146934000
# 7                                      Bangladesh   129155000
# 8                                           Japan   126714000
# 9                                         Nigeria   111506000
# 10                                         Mexico    98881000
# 11                                        Germany    82164700
# 12                                        Vietnam    79832000
# 13                                    Philippines    75967000
# 14                                          Egypt    68470000
# 15                                           Iran    67702000
# 16                                         Turkey    66591000
# 17                                       Ethiopia    62565000
# 18                                       Thailand    61399000
# 19                                 United Kingdom    59623400
# 20                                         France    59225700
# 21                                          Italy    57680000
# 22          Congo, The Democratic Republic of the    51654000
# 23                                        Ukraine    50456000
# 24                                    South Korea    46844000
# 25                                        Myanmar    45611000
# 26                                       Colombia    42321000
# 27                                   South Africa    40377000
# 28                                          Spain    39441700
# 29                                         Poland    38653600
# ..                                            ...         ...
# 209                                 Liechtenstein       32300
# 210                                    San Marino       27000
# 211                                     Gibraltar       25000
# 212                       Virgin Islands, British       21000
# 213                                  Cook Islands       20000
# 214                                         Palau       19000
# 215                      Turks and Caicos Islands       17000
# 216                             Wallis and Futuna       15000
# 217                                         Nauru       12000
# 218                                        Tuvalu       12000
# 219                                    Montserrat       11000
# 220                                      Anguilla        8000
# 221                     Saint Pierre and Miquelon        7000
# 222                                  Saint Helena        6000
# 223                        Svalbard and Jan Mayen        3200
# 224                              Christmas Island        2500
# 225                                       Tokelau        2000
# 226                                Norfolk Island        2000
# 227                                          Niue        2000
# 228                              Falkland Islands        2000
# 229                 Holy See (Vatican City State)        1000
# 230                       Cocos (Keeling) Islands         600
# 231                                      Pitcairn          50
# 232                                 Bouvet Island           0
# 233                British Indian Ocean Territory           0
# 234  South Georgia and the South Sandwich Islands           0
# 235          United States Minor Outlying Islands           0
# 236             Heard Island and McDonald Islands           0
# 237                   French Southern territories           0
# 238                                    Antarctica           0
#
# [239 rows x 2 columns]
